# %%
import os
import numpy as np
import pandas as pd
import mne
from mne.preprocessing import ICA
import pywt
from scipy import signal
from scipy.interpolate import Rbf
from PIL import Image
from tqdm import tqdm
from joblib import Parallel, delayed
import warnings
warnings.filterwarnings("ignore")
mne.set_log_level("WARNING")

# %%
import os
import shutil

def clear_directory(directory_path):
    if not os.path.exists(directory_path):
        print(f"Directory does not exist: {directory_path}")
        return
    
    for filename in os.listdir(directory_path):
        file_path = os.path.join(directory_path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)  # Delete file or symbolic link
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Delete directory and its contents
        except Exception as e:
            print(f"Failed to delete {file_path}. Reason: {e}")

directory_to_clear = "/kaggle/working/"
clear_directory(directory_to_clear)
print(f"Cleared all contents in: {directory_to_clear}")

# %%
label_num = {'Seizure': 0, 'GPD': 1, 'LPD': 2, 'GRDA': 3, 'LRDA': 4, 'Other': 5}
channel_names = ['Fp1','F3','C3','P3','F7','T3','T5','O1','Fz','Cz','Pz','Fp2','F4','C4','P4','F8','T4','T6','O2']
channel_types = ['eeg'] * len(channel_names)
sfreq = 200

channel_indices = {name: idx for idx, name in enumerate(channel_names)}

grid_structure = [
    [0,    'Fp1', 0,    'Fp2', 0],
    ['F7', 'F3',  'Fz', 'F4',  'F8'],
    ['T3', 'C3',  'Cz', 'C4',  'T4'],
    ['T5', 'P3',  'Pz', 'P4',  'T6'],
    [0,    'O1',  0,    'O2',  0]
]

# %%
def signal_processing(a,b):
    eeg = pd.read_parquet("/kaggle/input/hms-harmful-brain-activity-classification/train_eegs/"+str(a)+".parquet")
    eeg = eeg[int(b)*200:int(50+b)*200] 
    eeg.fillna(eeg.mean(), inplace = True) 
    eeg_data = eeg.iloc[:,:-1].to_numpy().T  
    
    info = mne.create_info(ch_names = channel_names, sfreq = sfreq, ch_types = channel_types)
    raw = mne.io.RawArray(eeg_data, info)
    std_montage = mne.channels.make_standard_montage('standard_1020')
    raw.set_montage(std_montage)

    raw.notch_filter(60)

    raw.filter(l_freq = 1, h_freq = 50, method = 'iir', iir_params = None)

    raw_data = raw.get_data() 
    raw_times = raw.times
    info = raw.info 
    normalized_eeg = mne.baseline.rescale(raw_data, raw_times, baseline = (None, None), mode = 'mean')
    normalized_eeg = mne.io.RawArray(normalized_eeg, info)

    return normalized_eeg

# %%
def wavelet_enhanced_ica(normalized_eeg):
    ica = mne.preprocessing.ICA(n_components = 19, method = 'infomax', fit_params = dict(extended=True), max_iter = 'auto')
    ica.fit(normalized_eeg.copy())
    
    data = normalized_eeg.get_data()
    mixing_matrix = ica.mixing_matrix_
    unmixing_matrix = ica.unmixing_matrix_
    pca_components = ica.pca_components_
    pca_mean = ica.pca_mean_
    n_pca_components = ica.n_components_

    data_centered = data - pca_mean[:, np.newaxis]
    pca_data = np.dot(pca_components[:n_pca_components], data_centered)
    ica_sources = np.dot(unmixing_matrix, pca_data)

    denoised_components = np.zeros(data.shape)
    wavelet_family = 'db4'
    resolution = 5
    
    for i in range(19):
        coefficients = pywt.wavedec(ica_sources[i], wavelet = wavelet_family, level = resolution)
        sigma = (1/0.6745) * np.median(np.abs(coefficients[5] - np.median(coefficients[5]))) 
        threshold = sigma * np.sqrt(2 * np.log(len(coefficients[5])/sfreq)) 
        coefficients[1:] = [np.where(np.abs(coeff) > threshold, 0, coeff) for coeff in coefficients[1:]]
        denoised_components[i] = pywt.waverec(coefficients, wavelet = wavelet_family)
        
    ica_reconstructed = np.dot(mixing_matrix, denoised_components)
    reconstructed_data = np.dot(pca_components[:n_pca_components].T, ica_reconstructed)
    reconstructed_data += pca_mean[:, np.newaxis] # numpy.ndarray:shape(19, 10000):data.shape

    return reconstructed_data # (n_channels, n_samples)

# %%
def feature_maps(eeg_data):
    representation_matrix = np.zeros((10000, 5, 5))
    for t in range(10000):
        for i in range(5):
            for j in range(5):
                channel = grid_structure[i][j]
                if channel != 0: 
                    representation_matrix[t, i, j] = eeg_data[channel_indices[channel], t]
    
    rbf_interpolated_data = np.zeros_like(representation_matrix)
    x_grid, y_grid = np.meshgrid(np.arange(5), np.arange(5))
    known_positions = []
    known_values = []

    for t in range(10000):
        known_positions = []
        known_values = []
        for i in range(5):
            for j in range(5):
                if grid_structure[i][j] != 0:  
                    known_positions.append([i, j])
                    known_values.append(representation_matrix[t, i, j])
        known_positions = np.array(known_positions)
        known_values = np.array(known_values)
        if len(known_values) == 0:
            continue
        rbf = Rbf(known_positions[:, 0], known_positions[:, 1], known_values, function='gaussian')
        for i in range(5):
            for j in range(5):
                if grid_structure[i][j] == 0: 
                    rbf_interpolated_data[t, i, j] = rbf(i, j)
                else: 
                    rbf_interpolated_data[t, i, j] = representation_matrix[t, i, j]
                    
    # feature_maps = np.zeros((10000, 64, 64))
    # dim = (64, 64)
    # for i in range(10000):
    #     image = Image.fromarray(rbf_interpolated_data[i])
    #     resized_map = image.resize(dim, Image.Resampling.BICUBIC)
    #     resized_map_array = np.array(resized_map)
    #     feature_maps[i] = resized_map_array

    # extended_feature_maps = np.expand_dims(feature_maps, axis=1)

    extended_feature_maps = np.expand_dims(rbf_interpolated_data, axis=1)
    
    window_size = 5
    T, C, H, W = extended_feature_maps.shape
    assert T % window_size == 0, "Time dimension must be divisible by window_size"
    T_new = T // window_size
    reduced_feature_map = np.median(extended_feature_maps.reshape(T_new, window_size, C, H, W), axis=1)
    
    normalized_feature_map = np.empty_like(reduced_feature_map, dtype=np.float32)
    
    for i in range(reduced_feature_map.shape[0]):
        img = reduced_feature_map[i, 0]
        min_val = np.min(img)
        max_val = np.max(img)
        if max_val > min_val:
            norm_img = (img - min_val) / (max_val - min_val)
        else:
            norm_img = img  
        normalized_feature_map[i, 0] = norm_img
        
    return normalized_feature_map

# %%
# train_df = pd.read_csv('/kaggle/input/csv-files/train_sampled.csv', usecols=['eeg_id', 'eeg_label_offset_seconds', 'eeg_sub_id', 'expert_consensus'])

# total_rows = len(train_df)

# split1 = total_rows // 6
# split2 = 2 * split1
# split3 = 3 * split1
# split4 = 4 * split1
# split5 = 5 * split1

# df_part1 = train_df.iloc[:split1]
# df_part2 = train_df.iloc[split1:split2]
# df_part3 = train_df.iloc[split2:split3]
# df_part4 = train_df.iloc[split3:split4]
# df_part5 = train_df.iloc[split4:split5]
# df_part6 = train_df.iloc[split5:]


# output_dir = '/kaggle/working/Train_5' 
# os.makedirs(output_dir, exist_ok = True)

# %%
test_df = pd.read_csv('/kaggle/input/csv-files/test_sampled.csv', usecols=['eeg_id', 'eeg_label_offset_seconds', 'eeg_sub_id', 'expert_consensus'])

total_rows_test = len(test_df)
split_test = total_rows_test // 2

df_test_part1 = test_df.iloc[:split_test]
df_test_part2 = test_df.iloc[split_test:]

output_dir_test = '/kaggle/working/Test_1' 
os.makedirs(output_dir_test, exist_ok=True)

# %%
# import logging

# mne_logger = logging.getLogger('mne')
# mne_logger.setLevel(logging.WARNING)

# tqdm_kwargs = {
#     'desc': 'Processing EEGs',
#     'leave': False,  
#     'dynamic_ncols': True, 
#     'bar_format': '{l_bar}{bar}| {n_fmt}/{total_fmt}'  
# }

# %%
# # test_df = pd.read_csv('/kaggle/input/csv-files/test_sampled.csv', usecols=['eeg_id', 'eeg_label_offset_seconds', 'eeg_sub_id', 'expert_consensus'])

# def process_eeg(eeg_id, df, output_dir, label_num):
#     eeg_data = df[df["eeg_id"] == eeg_id]
#     for _, row in eeg_data.iterrows():
#         a = row["eeg_id"]
#         b = int(row["eeg_label_offset_seconds"])
#         c = row["eeg_sub_id"]
#         label = label_num[row['expert_consensus']]
        
#         normalized_eeg = signal_processing(a, b)
#         artifact_corrected_data = wavelet_enhanced_ica(normalized_eeg)  # (19, 10000)
#         reduced_feature_maps = feature_maps(artifact_corrected_data)    # (2000, 1, 5, 5)

#         np.savez(f"{output_dir}/{a}_{c}_feature_maps.npz", features = reduced_feature_maps, label = np.array([label]))

# Parallel(n_jobs=4)(delayed(process_eeg)(eeg_id, df_part1, output_dir, label_num) for eeg_id in tqdm(df_part1["eeg_id"].unique(), **tqdm_kwargs))

# %%
import os
import sys
from tqdm import tqdm
from joblib import Parallel, delayed
import logging
import mne

mne.set_log_level(verbose="ERROR")  
logging.getLogger('mne').setLevel(logging.ERROR)
logging.getLogger('joblib').setLevel(logging.ERROR)

def suppress_output(func):
    def wrapper(*args, **kwargs):
        # Redirect stdout/stderr to devnull
        original_stdout = sys.stdout
        original_stderr = sys.stderr
        sys.stdout = open(os.devnull, 'w')
        sys.stderr = open(os.devnull, 'w')
        
        try:
            result = func(*args, **kwargs)
        finally:
            # Restore stdout/stderr
            sys.stdout = original_stdout
            sys.stderr = original_stderr
        return result
    return wrapper

@suppress_output
def process_eeg(eeg_id, df, output_dir, label_num):
    eeg_data = df[df["eeg_id"] == eeg_id]
    for _, row in eeg_data.iterrows():
        a = row["eeg_id"]
        b = int(row["eeg_label_offset_seconds"])
        c = row["eeg_sub_id"]
        label = label_num[row['expert_consensus']]
        
        normalized_eeg = signal_processing(a, b)
        artifact_corrected_data = wavelet_enhanced_ica(normalized_eeg)  # (19, 10000)
        reduced_feature_maps = feature_maps(artifact_corrected_data)    # (2000, 1, 5, 5)

        np.savez(f"{output_dir}/{a}_{c}_feature_maps.npz", features=reduced_feature_maps, label=np.array([label]))


tqdm_params = {
    'desc': 'Processing EEGs',
    'bar_format': '{l_bar}{bar}| {n_fmt}/{total_fmt} [Elapsed: {elapsed}, Remaining: {remaining}]',
    'leave': False
}

Parallel(n_jobs=4)(
    delayed(process_eeg)(eeg_id, df_test_part1, output_dir_test, label_num) 
    for eeg_id in tqdm(df_test_part1["eeg_id"].unique(), **tqdm_params)
)
# Out:
# Processing EEGs:   0%|          | 0/1914 [Elapsed: 00:00, Remaining: ?]
#
# Processing EEGs:   0%|          | 8/1914 [Elapsed: 00:19, Remaining: 1:17:09]

# %%
# !zip -r Train_4.zip Train_4
# Out:
#   adding: Train_4/ (stored 0%)
#   adding: Train_4/3562276716_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3258218061_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/3123865097_17_feature_maps.npz (deflated 15%)
#   adding: Train_4/2830329992_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1136493055_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/1562662023_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1454127370_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/518192282_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2469408774_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4226704122_12_feature_maps.npz (deflated 15%)
#   adding: Train_4/2446242925_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/1947784260_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2853295629_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/3762078156_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2040599209_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/737668235_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/797130385_18_feature_maps.npz (deflated 15%)
#   adding: Train_4/3940136820_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3269182629_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3769843139_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1887951160_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2626660733_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/90521273_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1534034564_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/794810531_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/407845839_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2125449393_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1574623400_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1725401841_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2897817455_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2733044584_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2333880986_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3864249594_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1136493055_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3897649170_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/2770282032_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1523788615_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2356549900_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2842486682_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/989494538_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2742099056_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1733227160_6_feature_maps.npz (deflated 14%)
#   adding: Train_4/3353826354_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/396055097_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/936283997_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1870583103_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3498729387_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/493426225_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1661472985_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3877460602_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/943850829_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/1362310419_2_feature_maps.npz (deflated 16%)
#   adding: Train_4/560847385_2_feature_maps.npz (deflated 16%)
#   adding: Train_4/123433820_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1359538825_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/135038403_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/36280366_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3832216758_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/376906738_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/268724452_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1141442028_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4196053488_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3883919346_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2134947401_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1870817419_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3436463038_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1806083415_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/128271906_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3213373524_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1839966899_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2075427446_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/200805101_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3159682175_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1931108076_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/3580650910_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2954606718_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3643896863_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/185317589_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2250593909_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2203315697_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/978435955_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1829863278_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/686738745_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1748528321_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2469408774_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1658643146_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/1706196508_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1280566343_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1432606516_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4156121621_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/29194495_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2200247100_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1065039525_8_feature_maps.npz (deflated 14%)
#   adding: Train_4/3426266318_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1930931118_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1264130563_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4289552619_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2299329986_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1955787542_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/26560372_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2746065239_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/577794603_16_feature_maps.npz (deflated 14%)
#   adding: Train_4/3855462020_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3078618999_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3935819849_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1604371226_0_feature_maps.npz (deflated 27%)
#   adding: Train_4/496868437_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/704367771_10_feature_maps.npz (deflated 15%)
#   adding: Train_4/3724126130_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/2313862496_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3279338815_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1324123464_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2125040011_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2575161324_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/72814101_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/31199864_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3172190152_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3469743615_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2686348081_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2188084953_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1505734463_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/519397310_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/1117257962_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4078897390_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1923985242_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2583028467_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1165410966_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1891397650_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/3671962049_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3616901556_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_125_feature_maps.npz (deflated 15%)
#   adding: Train_4/3970810691_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2227131552_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1653954013_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/4146942366_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3342644700_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/2210344449_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4155980404_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/3634948739_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1668268138_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3141821273_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1657832818_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/3017775275_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3227474705_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3573637636_29_feature_maps.npz (deflated 15%)
#   adding: Train_4/4294858825_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2771884262_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/524816337_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2272233771_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/972818192_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2130289282_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/915752866_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/213714167_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3227984206_0_feature_maps.npz (deflated 16%)
#   adding: Train_4/1080879993_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/715384917_7_feature_maps.npz (deflated 14%)
#   adding: Train_4/4173919760_9_feature_maps.npz (deflated 15%)
#   adding: Train_4/681981786_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2804637913_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/805166858_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/300031644_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2491813643_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2873477621_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3626786720_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/3436463038_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2657149852_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/440346204_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1847483811_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3154236876_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/512230501_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1776803024_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1670688336_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3792223532_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1995944548_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3022291213_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2817298256_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2102314742_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_108_feature_maps.npz (deflated 15%)
#   adding: Train_4/542097092_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1244497090_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/786298424_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/222576618_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/4185571901_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3008466337_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/4055204056_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2083647936_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3055657336_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/4277314868_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1602193026_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2014046435_13_feature_maps.npz (deflated 14%)
#   adding: Train_4/720560960_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1960233219_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/358676549_9_feature_maps.npz (deflated 14%)
#   adding: Train_4/2440656952_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/918510134_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2885855087_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3060693151_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/527970310_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3821205490_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/80952273_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3794481327_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/246921487_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/62723014_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3015454589_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3342644700_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/4211983398_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3036732119_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/325450547_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1401179064_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2266133766_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1399596511_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3985018091_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2050237561_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/72814101_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/174530290_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2673744884_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2189729740_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1605037033_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/333524339_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1214328023_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2813857114_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1583111589_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/316750397_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3842940881_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/872179290_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2567768220_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/3486874570_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/2674987427_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/522951328_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/321762073_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1481872137_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/387459778_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2853804909_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2326371532_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3947918181_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2332737806_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2233953579_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3735347828_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/192126763_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2234572696_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/1193159515_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/759770222_9_feature_maps.npz (deflated 15%)
#   adding: Train_4/1939502010_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2050085077_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/2989237241_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/3888624616_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1426331207_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2272411063_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2751944517_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/409023353_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3554617582_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3415305661_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/505684073_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1706203525_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3195189909_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/815573824_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/921585502_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/4159720978_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/3251992499_0_feature_maps.npz (deflated 32%)
#   adding: Train_4/2953996231_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1313696047_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1658643146_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/1677711045_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/3289750352_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3017775275_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/110891506_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/228900026_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2670438781_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3719868297_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/3978113092_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1146932979_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4152069633_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/897329476_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/983735392_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/3070701761_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/273244866_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/138040007_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1387100678_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_96_feature_maps.npz (deflated 15%)
#   adding: Train_4/2424030089_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3942119896_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3188191469_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3060080276_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/3746200913_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3550396998_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/495223489_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/522951328_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2449876091_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4126615105_37_feature_maps.npz (deflated 15%)
#   adding: Train_4/3918662578_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1993931554_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1774560837_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/277419368_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/413022255_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1565098068_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/2489530628_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/796358324_12_feature_maps.npz (deflated 15%)
#   adding: Train_4/3620475668_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1619540176_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/1407959278_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1436586189_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3378901168_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1931108076_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/1227233361_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2044050606_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3105693830_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/2717660244_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/918950919_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2475639175_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1298243791_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1618770996_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/805619134_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/2582747532_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1277613710_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3670022285_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3409511189_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_145_feature_maps.npz (deflated 15%)
#   adding: Train_4/3232962186_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1082211003_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/125309924_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3169557321_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4148511240_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/3151974031_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/2516143828_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1663137784_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2575161324_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/686614421_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/2265908441_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1504413365_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3314170030_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/505168156_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/108795029_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/2875763093_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2526944592_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3197558185_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4171147147_6_feature_maps.npz (deflated 14%)
#   adding: Train_4/3745881664_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/575307399_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/888563500_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/684938429_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3523679416_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3579618016_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/370581472_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1751984218_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2319210191_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/661843354_11_feature_maps.npz (deflated 15%)
#   adding: Train_4/3348102386_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/106141507_0_feature_maps.npz (deflated 18%)
#   adding: Train_4/3729510166_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/1633767263_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1085206902_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3844816739_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/2689829837_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1008331981_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1940288077_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2701497036_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/417262363_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1687004465_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1460778765_85_feature_maps.npz (deflated 15%)
#   adding: Train_4/3515611568_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2387889264_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4130394003_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3404232095_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2736158074_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/760613088_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_14_feature_maps.npz (deflated 15%)
#   adding: Train_4/3162503967_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4166604057_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3001010711_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1540938016_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/4263251837_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/2466764682_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4293144208_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2311656498_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4159720978_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/1929346710_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3705730929_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1891684169_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/722966525_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1033944434_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3208562745_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4226188962_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4169785695_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4074907915_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/726013670_9_feature_maps.npz (deflated 15%)
#   adding: Train_4/1376294683_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1180257155_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/277419368_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/3283854537_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2175619717_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2033256541_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1865491009_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/935909304_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1805451196_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2121745558_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/902124230_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2149526820_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3361268909_6_feature_maps.npz (deflated 14%)
#   adding: Train_4/2423997346_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3548348860_16_feature_maps.npz (deflated 15%)
#   adding: Train_4/3778671224_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1744447154_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/32210120_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/51360893_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/163693460_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/989810287_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2435030583_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1603904777_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3098812080_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/884153467_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/3024941983_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1280779468_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/370912557_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2446242925_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1648429038_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4241139693_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/866414788_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/268724452_0_feature_maps.npz (deflated 16%)
#   adding: Train_4/1428134089_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1199916863_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1822978367_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/478092706_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1220082386_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1570071409_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/252153427_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/344378551_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2276240743_2_feature_maps.npz (deflated 17%)
#   adding: Train_4/957390255_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/2820128527_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4091711677_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1639464114_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1527163462_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1258579905_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2358826065_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4071136768_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2092618900_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3943643843_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1446184419_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3599587598_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1080879993_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/2005506103_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/670737301_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3229584598_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1327593135_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4103082069_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2296572285_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/908452219_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2020179920_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/330434444_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/510279183_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1938815701_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3888624616_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/724989966_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3814203234_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1608764006_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1134996249_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/648127958_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/3824275430_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2144872561_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/1701530020_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/352392554_11_feature_maps.npz (deflated 15%)
#   adding: Train_4/4249475128_16_feature_maps.npz (deflated 15%)
#   adding: Train_4/3978200112_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1265605713_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/830892788_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1359025604_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1788946617_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/3634948739_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3688402032_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/733692131_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1717719547_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/3319662512_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/359658806_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4127852490_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/889846355_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2469408774_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/3066869201_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1998433644_2_feature_maps.npz (deflated 16%)
#   adding: Train_4/44070693_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3449593499_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1746293113_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3056790824_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/287655550_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3419930366_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/8922554_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4268107623_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3695504164_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2717667131_25_feature_maps.npz (deflated 15%)
#   adding: Train_4/3756227759_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/4208710743_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1123995887_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1156839815_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/693415160_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/2063607933_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/635197321_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1456144752_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3345326191_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4029896468_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2831818165_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1131497067_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1612323413_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/522951328_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2913850145_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1671649672_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/837423495_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4036558938_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3971575294_17_feature_maps.npz (deflated 15%)
#   adding: Train_4/21557190_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1007580543_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/4187371622_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2838274867_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/3574845498_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1263489849_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/3883919346_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/4156121621_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/560070513_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3011633475_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1308493865_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2835245081_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1746454788_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2504511222_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4159720978_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/3161926366_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3478894673_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3339799714_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/389280251_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2617316271_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3254527491_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/574334861_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4002216548_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1385659869_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3657595281_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3725369933_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2558443537_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3558571171_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1239117806_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/537928490_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1159334316_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1867023112_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3950295649_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/856600255_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4045442935_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/601381758_8_feature_maps.npz (deflated 14%)
#   adding: Train_4/1378468467_88_feature_maps.npz (deflated 15%)
#   adding: Train_4/1665328816_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4068553523_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/628369060_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1342762907_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1928636161_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1683796878_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1524455268_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3196043951_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3902417345_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1722615148_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1855764885_41_feature_maps.npz (deflated 15%)
#   adding: Train_4/3762062338_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_97_feature_maps.npz (deflated 15%)
#   adding: Train_4/1855943137_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2742099056_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1934533581_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/897382440_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/3607088659_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1073878025_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3715579723_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3022110684_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1928636161_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/974646241_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1491221249_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1320944299_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/467413714_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2148256831_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3041256953_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3410387626_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1273580097_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2146167216_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2158351655_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/743592073_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/893864755_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1676887278_15_feature_maps.npz (deflated 15%)
#   adding: Train_4/4171147147_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1003814407_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2303640978_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1008426936_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3246176805_23_feature_maps.npz (deflated 15%)
#   adding: Train_4/1647730247_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2020179920_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3765628906_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3248814671_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/657950150_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/268581974_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2892075039_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/743592073_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/3568599450_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2968258196_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1677711045_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3664151178_2_feature_maps.npz (deflated 16%)
#   adding: Train_4/135847864_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2943286279_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/4234158649_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/898596714_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1937260101_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/793260552_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1720196518_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3372768378_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2044283321_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1417739562_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4155980404_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1865764826_11_feature_maps.npz (deflated 15%)
#   adding: Train_4/2234572696_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/579606339_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1540938016_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/2127466976_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3172489455_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/698867656_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2835245081_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3427295656_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3418283713_2_feature_maps.npz (deflated 17%)
#   adding: Train_4/1998433644_5_feature_maps.npz (deflated 16%)
#   adding: Train_4/80093115_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2011168169_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1715840273_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/791803727_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3168600033_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/283242036_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2105870870_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/801924332_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2411089963_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3944292495_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/108795029_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3742961020_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/759770222_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/1109755415_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1417932871_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3493788236_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/992887225_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4237170154_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2384240622_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2561274279_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3268408773_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1104057000_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1280513674_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/2582479301_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/442677193_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3344435312_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/499383502_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2329781557_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2950957659_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2653471564_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1300203568_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/520544768_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/2648297763_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/204426353_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1607138617_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3330141099_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3091381765_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2157491736_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4212557384_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/365572327_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2274729731_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/976520675_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1695525893_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/2549282438_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/919379987_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2526944592_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/564145269_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2831354131_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/723271147_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3873865587_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_46_feature_maps.npz (deflated 15%)
#   adding: Train_4/1018200965_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3361268909_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3197558185_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/1058522598_8_feature_maps.npz (deflated 14%)
#   adding: Train_4/2285391838_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2020179920_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/210840280_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3007428672_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3278626166_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/2303640978_20_feature_maps.npz (deflated 15%)
#   adding: Train_4/1687004465_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3614997687_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/3808173057_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1643190370_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1307362978_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1635951263_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2519436496_19_feature_maps.npz (deflated 15%)
#   adding: Train_4/1915888302_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/1715840273_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1804272664_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2892890503_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4036608169_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2782459982_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4191248502_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/623378160_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/637469415_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3821205490_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/219790007_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2729924426_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/608013764_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/1001369401_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/850021095_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/334167781_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3351023583_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1395182367_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/453401410_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/4144775460_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/617516151_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2696958663_10_feature_maps.npz (deflated 15%)
#   adding: Train_4/119858355_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/793260552_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/449754997_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1481872137_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/2478390823_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/321762073_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/371453857_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/2243329460_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/256888363_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2621929655_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3353826354_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3357654647_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1439901768_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4261965329_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1744447154_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/335092563_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3166028640_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/1702532153_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3328769716_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3936987921_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3407921069_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2481023995_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_100_feature_maps.npz (deflated 15%)
#   adding: Train_4/1358971320_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3553085473_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/333524339_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4160351544_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3167711822_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3180444652_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/674421514_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3125138789_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1491221249_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2960731299_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2482955557_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3269046909_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1322156489_0_feature_maps.npz (deflated 17%)
#   adding: Train_4/1603240981_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/942146219_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2506826985_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1722615148_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/686614421_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/661843354_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/667415534_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1157937925_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2677827041_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3301040408_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1075963156_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/2843667726_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2630069947_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/83011251_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4019431782_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2234972987_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1010795734_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3733778162_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3664278947_1_feature_maps.npz (deflated 15%)
# ...
#   adding: Train_4/498082028_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1651112940_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4052175701_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2897296040_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2389202906_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/3898201975_9_feature_maps.npz (deflated 15%)
#   adding: Train_4/2829880083_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2839673372_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4127852490_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2116521549_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2205157868_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2894810773_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2645295197_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2950555718_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1476988697_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/2654430657_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2504629584_6_feature_maps.npz (deflated 14%)
#   adding: Train_4/1923196888_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3070031180_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1379873365_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/323798635_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/4042661191_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3173229120_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/844022557_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1048893097_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/229636553_13_feature_maps.npz (deflated 15%)
#   adding: Train_4/3507607732_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1975563008_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/3484077983_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/1152986658_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/2969996802_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4204776876_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/503119398_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2923553793_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1757280867_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3441687785_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1173802165_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/897183978_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2310432734_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1262696025_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3331623884_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2580400675_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1157377277_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3507352781_0_feature_maps.npz (deflated 29%)
#   adding: Train_4/2198957446_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/704367771_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1452595740_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1399237886_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/2891994609_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/122762465_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1803051097_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3641187430_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3529130807_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2422895257_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2467464617_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3313746829_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/3616901556_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1385659869_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/4254997127_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/578367810_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/728345361_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/805166858_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/2830532215_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2395395005_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/374847603_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2006872912_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1241711686_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3362634165_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4071899005_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3302960876_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2256116308_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1940203396_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1643713936_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/3638264461_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/661843354_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/2622430129_2_feature_maps.npz (deflated 14%)
#   adding: Train_4/2754586297_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4028995425_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/1322156489_1_feature_maps.npz (deflated 17%)
#   adding: Train_4/2862857715_7_feature_maps.npz (deflated 14%)
#   adding: Train_4/3876807224_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2653148053_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/3440508812_11_feature_maps.npz (deflated 15%)
#   adding: Train_4/51360893_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3731967853_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3838859089_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1718214221_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/941066906_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/73783114_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3807904140_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/704367771_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/3902064019_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2694902665_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1472804967_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4187682795_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3146689694_17_feature_maps.npz (deflated 15%)
#   adding: Train_4/485707667_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2751025154_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2109261074_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2450201272_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/3451660790_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1617720796_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1018200965_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/352100210_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2245396346_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3335542761_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/511967446_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1584823503_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/590991515_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/85730354_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/837430328_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2091960775_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/849641501_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3693522943_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3671342136_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/1654075283_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4205912907_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/888118801_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/26560372_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/463990966_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/560847385_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3468904156_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2599026635_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1052897805_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/264957320_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2793158296_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1313568412_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2902561706_8_feature_maps.npz (deflated 15%)
#   adding: Train_4/424908271_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3393291042_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/18263267_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2838358862_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2130289282_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3729510166_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3126415448_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/656804144_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3031106309_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/279879270_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/964218233_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/805166858_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2635472306_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2204043652_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1721634951_3_feature_maps.npz (deflated 14%)
#   adding: Train_4/473141450_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4019212620_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2789844437_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/807741673_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/293155110_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2095882572_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3911426153_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/800870509_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/3751928141_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1154873987_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/4155998098_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/301692511_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1943782762_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/772592027_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/39051070_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2873477621_6_feature_maps.npz (deflated 15%)
#   adding: Train_4/1085664125_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/647798223_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4096587877_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1666967547_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3612353156_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/324211159_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/338426973_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2332834753_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1499314999_19_feature_maps.npz (deflated 14%)
#   adding: Train_4/464391702_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/1797000067_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3589143372_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/573344694_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1460301022_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2180232173_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/89783277_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1152986658_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1763739459_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2312823072_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/852674541_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/858109871_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3844816739_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1396959927_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/1192580869_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/971460492_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3565730699_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3410387626_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1683178846_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/3737225419_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2715162145_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/827449232_7_feature_maps.npz (deflated 14%)
#   adding: Train_4/2687138124_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1706196508_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1668268138_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/183004313_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/617107353_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3123865097_15_feature_maps.npz (deflated 15%)
#   adding: Train_4/2860837259_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/3481352609_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2663292818_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2273786560_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3330141099_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/3563585193_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/150957647_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2030552558_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3345914754_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/69489622_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/958064054_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1683796878_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/650078305_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/983735392_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/4045442935_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3232757274_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/1835624711_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2320189256_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1065039525_5_feature_maps.npz (deflated 14%)
#   adding: Train_4/3556682378_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/3873152051_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/868873573_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/551399564_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1019419868_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/1186716127_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3433432451_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3717535107_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/1342762907_4_feature_maps.npz (deflated 15%)
#   adding: Train_4/512230501_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/1523347718_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/269020598_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2315697534_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1307362978_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1407381869_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/248498717_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2659833451_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2621242676_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2437685184_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/2952578175_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/4287296555_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2025709442_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/918762139_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3262717753_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/3278626166_4_feature_maps.npz (deflated 14%)
#   adding: Train_4/1767856219_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/2789061822_5_feature_maps.npz (deflated 15%)
#   adding: Train_4/4011621314_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/3865174444_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/971456601_3_feature_maps.npz (deflated 15%)
#   adding: Train_4/4209276767_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/527047520_1_feature_maps.npz (deflated 14%)
#   adding: Train_4/64917920_7_feature_maps.npz (deflated 15%)
#   adding: Train_4/4159118721_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/2550609156_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3007439107_0_feature_maps.npz (deflated 14%)
#   adding: Train_4/2932624100_1_feature_maps.npz (deflated 15%)
#   adding: Train_4/1418257229_0_feature_maps.npz (deflated 15%)
#   adding: Train_4/3693485834_2_feature_maps.npz (deflated 15%)
#   adding: Train_4/2602368892_0_feature_maps.npz (deflated 15%)

# %%
from IPython.display import FileLink 
FileLink(r'Train_4.zip')
# Out:
# /kaggle/working/Train_4.zip
