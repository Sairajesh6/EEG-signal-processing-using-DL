# %%
import os
import numpy as np
import pandas as pd
import mne
from mne.preprocessing import ICA
import pywt
from scipy import signal
from scipy.interpolate import Rbf
from PIL import Image
from tqdm import tqdm
from joblib import Parallel, delayed
import warnings
warnings.filterwarnings("ignore")
mne.set_log_level("WARNING")

# %%
label_num = {'Seizure': 0, 'GPD': 1, 'LPD': 2, 'GRDA': 3, 'LRDA': 4, 'Other': 5}
channel_names = ['Fp1','F3','C3','P3','F7','T3','T5','O1','Fz','Cz','Pz','Fp2','F4','C4','P4','F8','T4','T6','O2']
channel_types = ['eeg'] * len(channel_names)
sfreq = 200

channel_indices = {name: idx for idx, name in enumerate(channel_names)}

grid_structure = [
    [0,    'Fp1', 0,    'Fp2', 0],
    ['F7', 'F3',  'Fz', 'F4',  'F8'],
    ['T3', 'C3',  'Cz', 'C4',  'T4'],
    ['T5', 'P3',  'Pz', 'P4',  'T6'],
    [0,    'O1',  0,    'O2',  0]
]

# %%
def signal_processing(a,b):
    eeg = pd.read_parquet("/kaggle/input/hms-harmful-brain-activity-classification/train_eegs/"+str(a)+".parquet")
    eeg = eeg[int(b)*200:int(50+b)*200] #[start, stop, step] #(n_samples, n_channels)
    eeg.fillna(eeg.mean(), inplace = True) 
    eeg_data = eeg.iloc[:,:-1].to_numpy().T  #(n_channels, n_samples)
    
    info = mne.create_info(ch_names = channel_names, sfreq = sfreq, ch_types = channel_types)
    raw = mne.io.RawArray(eeg_data, info)
    std_montage = mne.channels.make_standard_montage('standard_1020')
    raw.set_montage(std_montage)

    raw.notch_filter(60)

    raw.filter(l_freq = 1, h_freq = 50, method = 'iir', iir_params = None)

    raw_data = raw.get_data() 
    raw_times = raw.times
    info = raw.info 
    normalized_eeg = mne.baseline.rescale(raw_data, raw_times, baseline = (None, None), mode = 'mean')
    normalized_eeg = mne.io.RawArray(normalized_eeg, info)

    return normalized_eeg

# %%
def wavelet_enhanced_ica(normalized_eeg):
    ica = mne.preprocessing.ICA(n_components = 19, method = 'infomax', fit_params = dict(extended=True), max_iter = 'auto')
    ica.fit(normalized_eeg.copy())
    
    data = normalized_eeg.get_data()
    mixing_matrix = ica.mixing_matrix_
    unmixing_matrix = ica.unmixing_matrix_
    pca_components = ica.pca_components_
    pca_mean = ica.pca_mean_
    n_pca_components = ica.n_components_

    data_centered = data - pca_mean[:, np.newaxis]
    pca_data = np.dot(pca_components[:n_pca_components], data_centered)
    ica_sources = np.dot(unmixing_matrix, pca_data)

    denoised_components = np.zeros(data.shape)
    wavelet_family = 'db4'
    resolution = 5
    
    for i in range(19):
        coefficients = pywt.wavedec(ica_sources[i], wavelet = wavelet_family, level = resolution)
        sigma = (1/0.6745) * np.median(np.abs(coefficients[5] - np.median(coefficients[5]))) 
        threshold = sigma * np.sqrt(2 * np.log(len(coefficients[5])/sfreq)) 
        coefficients[1:] = [np.where(np.abs(coeff) > threshold, 0, coeff) for coeff in coefficients[1:]]
        denoised_components[i] = pywt.waverec(coefficients, wavelet = wavelet_family)
        
    ica_reconstructed = np.dot(mixing_matrix, denoised_components)
    reconstructed_data = np.dot(pca_components[:n_pca_components].T, ica_reconstructed)
    reconstructed_data += pca_mean[:, np.newaxis] # numpy.ndarray:shape(19, 10000):data.shape

    return reconstructed_data # (n_channels, n_samples)

# %%
def feature_maps(eeg_data):
    representation_matrix = np.zeros((10000, 5, 5))
    for t in range(10000):
        for i in range(5):
            for j in range(5):
                channel = grid_structure[i][j]
                if channel != 0: 
                    representation_matrix[t, i, j] = eeg_data[channel_indices[channel], t]
    
    rbf_interpolated_data = np.zeros_like(representation_matrix)
    x_grid, y_grid = np.meshgrid(np.arange(5), np.arange(5))
    known_positions = []
    known_values = []

    for t in range(10000):
        known_positions = []
        known_values = []
        for i in range(5):
            for j in range(5):
                if grid_structure[i][j] != 0:  
                    known_positions.append([i, j])
                    known_values.append(representation_matrix[t, i, j])
        known_positions = np.array(known_positions)
        known_values = np.array(known_values)
        if len(known_values) == 0:
            continue
        rbf = Rbf(known_positions[:, 0], known_positions[:, 1], known_values, function='gaussian')
        for i in range(5):
            for j in range(5):
                if grid_structure[i][j] == 0: 
                    rbf_interpolated_data[t, i, j] = rbf(i, j)
                else: 
                    rbf_interpolated_data[t, i, j] = representation_matrix[t, i, j]
                    
    feature_maps = np.zeros((10000, 64, 64))
    dim = (64, 64)
    for i in range(10000):
        image = Image.fromarray(rbf_interpolated_data[i])
        resized_map = image.resize(dim, Image.Resampling.BICUBIC)
        resized_map_array = np.array(resized_map)
        feature_maps[i] = resized_map_array

    extended_feature_maps = np.expand_dims(feature_maps, axis=1)
    
    window_size = 200
    T, C, H, W = extended_feature_maps.shape
    assert T % window_size == 0, "Time dimension must be divisible by window_size"
    T_new = T // window_size
    reduced_feature_map = np.median(extended_feature_maps.reshape(T_new, window_size, C, H, W), axis=1)
    
    normalized_feature_map = np.empty_like(reduced_feature_map, dtype=np.float32)
    
    for i in range(reduced_feature_map.shape[0]):
        img = reduced_feature_map[i, 0]
        min_val = np.min(img)
        max_val = np.max(img)
        if max_val > min_val:
            norm_img = (img - min_val) / (max_val - min_val)
        else:
            norm_img = img  
        normalized_feature_map[i, 0] = norm_img
        
    return normalized_feature_map

# %%
# import os
# import shutil

# folder_path = '/kaggle/working/Train_1'

# if os.path.exists(folder_path):
#     if os.path.isdir(folder_path):
#         shutil.rmtree(folder_path)  # Deletes the folder and all its contents
#         print(f"{folder_path} has been deleted.")
#     else:
#         print(f"{folder_path} is not a directory.")
# else:
#     print(f"{folder_path} does not exist.")
# Out:
# /kaggle/working/Train_1 has been deleted.

# %%
train_df = pd.read_csv('/kaggle/input/csv-files/train_sampled.csv', usecols=['eeg_id', 'eeg_label_offset_seconds', 'eeg_sub_id', 'expert_consensus'])

total_rows = len(train_df)

split1 = total_rows // 3
split2 = 2 * (total_rows // 3)

df_part1 = train_df.iloc[:split1]  
df_part2 = train_df.iloc[split1:split2]  
df_part3 = train_df.iloc[split2:]  

half = len(df_part1) // 2
part1_1 = df_part1[:half]
part1_2 = df_part1[half:]

# %%
l = len(part1_2) // 2
part1_2_1 = part1_2[:l]
part1_2_2 = part1_2[l:]

# %%
# test_df = pd.read_csv('/kaggle/input/csv-files/test_sampled.csv', usecols=['eeg_id', 'eeg_label_offset_seconds', 'eeg_sub_id', 'expert_consensus'])

output_dir = '/kaggle/working/Train_1_2_2' 
os.makedirs(output_dir, exist_ok = True)


def process_eeg(eeg_id, df, output_dir, label_num):
    eeg_data = df[df["eeg_id"] == eeg_id]
    for _, row in eeg_data.iterrows():
        a = row["eeg_id"]
        b = int(row["eeg_label_offset_seconds"])
        c = row["eeg_sub_id"]
        label = label_num[row['expert_consensus']]
        
        normalized_eeg = signal_processing(a, b)
        artifact_corrected_data = wavelet_enhanced_ica(normalized_eeg)  # (19, 10000)
        reduced_feature_maps = feature_maps(artifact_corrected_data)            # (50, 1, 64, 64)

        np.savez(f"{output_dir}/{a}_{c}_feature_maps.npz", features = reduced_feature_maps, label = np.array([label]))

Parallel(n_jobs=4)(delayed(process_eeg)(eeg_id, part1_2_2, output_dir, label_num) for eeg_id in tqdm(part1_2_2["eeg_id"].unique()))
# Out:
# 100%|██████████| 834/834 [3:06:22<00:00, 13.41s/it]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# !zip -r Train_1_2_2.zip Train_1_2_2
# Out:
#   adding: Train_1_2_2/ (stored 0%)
#   adding: Train_1_2_2/3127951892_45_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2860052642_492_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3572672408_44_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4072150916_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/4233815620_105_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_589_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/429744439_22_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2259539799_421_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2922201798_2_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1596590162_65_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2654556255_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2436005794_0_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1309740482_7_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4233815620_57_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1612845714_68_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1596590162_270_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/839643180_71_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4233815620_64_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4096771384_36_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1641054670_549_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3204574831_39_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1957997047_78_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2860052642_423_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/653687449_5_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1403860944_14_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/431175263_21_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/653687449_65_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2509934535_8_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/717566795_137_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3938062014_13_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2353465632_0_feature_maps.npz (deflated 13%)
#   adding: Train_1_2_2/753481674_182_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3572672408_59_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2702157487_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2721684530_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2808950641_20_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3301091280_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/932738121_48_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2491654631_0_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1190503155_3_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1612845714_73_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3261575227_13_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3839535716_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2094852131_72_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/717566795_167_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_284_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1403860944_9_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/97221011_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3274420046_19_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/694389354_91_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2560892937_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_647_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2308002414_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3681836083_4_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3747058285_70_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3395187963_35_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/753481674_120_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1641054670_240_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/810024520_26_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/4007115462_18_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/694389354_111_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/344146772_4_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1881738908_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1187918693_19_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1403860944_17_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3727747246_26_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1596590162_110_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1156967300_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3367447082_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3839385026_16_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1254086231_2_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/653687449_13_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/810024520_11_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_636_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2663354018_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/694389354_11_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4007036594_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/753481674_150_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2340599172_22_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1612845714_63_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/332112789_8_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/429744439_17_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3241992339_22_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_264_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1758805110_5_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3178576528_0_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/839643180_80_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3747811723_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/918409487_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3710792652_6_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1391216195_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3375989355_0_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/119167896_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/119167896_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1016412282_10_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/770719727_3_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3522464877_6_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/596236591_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2367582787_19_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_485_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1026473133_9_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/665745699_9_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2666767757_15_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1672291799_7_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/4050543457_9_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4254742062_21_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1615245074_6_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/4233815620_115_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2259539799_235_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/286263734_8_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2802214724_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3989948588_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3747811723_5_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/810024520_18_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3833638406_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3747058285_39_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3065715583_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2740135854_19_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/352705021_51_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/
feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3088095149_23_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2965929795_97_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3816423613_28_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2140288474_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/143184490_7_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1058173302_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1405667816_223_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2129681272_13_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3636015289_20_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2234833327_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3223729364_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1596590162_164_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2798223837_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_231_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1499449066_6_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4018092903_16_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2259539799_238_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1327593077_86_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_563_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2097761111_12_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1891953107_49_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2590193801_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2934181405_14_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2860052642_67_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1327593077_42_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1641054670_151_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3572672408_50_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2087086294_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1463717064_5_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/562038473_109_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4246895013_9_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/849229366_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2503979556_8_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1492067494_6_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1409982356_44_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2340599172_67_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/4149000517_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1559899685_6_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2914041476_12_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/810024520_24_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3715407957_1_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3743052745_5_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2740135854_15_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2387018418_40_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1793812181_3_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1779230138_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/694389354_156_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1596590162_128_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2860052642_403_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2153980671_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3903364984_23_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1341074218_5_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1285832179_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1957997047_58_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3690440373_21_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2660162072_6_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2649037390_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3254156300_0_feature_maps.npz (deflated 19%)
#   adding: Train_1_2_2/2259539799_572_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1327593077_94_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/163506374_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1299105802_2_feature_maps.npz (deflated 14%)
#   adding: Train_1_2_2/659517089_1_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2094852131_119_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1254086231_8_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1201871280_37_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/409139131_13_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1482286616_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/744856643_20_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2882719839_139_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3636015289_38_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1668355055_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2366886773_6_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_486_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/694389354_82_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1249271153_3_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2721962370_0_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/932738121_11_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2143417174_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/179034757_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_299_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2860052642_329_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3747058285_154_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2802467149_13_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2248752928_21_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1327593077_99_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1901898601_3_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2314228464_3_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1128738777_151_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/352705021_41_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/216551560_39_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1068594966_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3199825285_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3476901677_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1300795281_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2259539799_297_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/554968692_20_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/3816423613_1_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1811164213_1_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1477530987_0_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2234833327_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/694389354_178_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1675567688_2_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2259539799_240_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3169501433_11_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1536526554_5_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2882719839_2_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1470287332_24_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1695880945_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2180640990_54_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3747811723_4_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1641054670_230_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/717566795_80_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/240035848_20_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3612782355_7_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3255856474_1_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/53167435_0_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/3345995940_2_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/344146772_2_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/1201871280_57_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/824981714_114_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/352705021_112_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/1596590162_116_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/429744439_27_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/877427445_13_feature_maps.npz (deflated 16%)
#   adding: Train_1_2_2/1390809947_7_feature_maps.npz (deflated 11%)
#   adding: Train_1_2_2/2753547919_7_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/2259539799_622_feature_maps.npz (deflated 12%)
#   adding: Train_1_2_2/659356734_1_feature_maps.npz (deflated 11%)

# %%
from IPython.display import FileLink 
FileLink(r'Train_1_2_2.zip')
# Out:
# /kaggle/working/Train_1_2_2.zip

# %%
import os
import shutil

folder_path = '/kaggle/working/Train_1_2'

if os.path.exists(folder_path):
    if os.path.isdir(folder_path):
        shutil.rmtree(folder_path)  # Deletes the folder and all its contents
        print(f"{folder_path} has been deleted.")
    else:
        print(f"{folder_path} is not a directory.")
else:
    print(f"{folder_path} does not exist.")
# Out:
# /kaggle/working/Train_1_2 has been deleted.

# %%
import os

file_path = '/kaggle/working/Train_1_2_1.zip'

if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} has been deleted.")
else:
    print(f"{file_path} does not exist.")
# Out:
# /kaggle/working/Train_1_2_1.zip has been deleted.

# %%
import os
print(os.path.exists('/kaggle/working/Train_1.zip'))
# Out:
# True
